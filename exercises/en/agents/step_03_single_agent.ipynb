# %% [markdown]
# # Step 3 — Single Agent (Runner)
#
# 🇬🇧 **English** (this notebook)
#
# This notebook just **runs and displays** your crew — for the full background, citations, and editing instructions, see [03-single-agent.md](03-single-agent.md). Edit `agents.yaml`, `tasks.yaml`, and `crew.py` as real files first (a notebook cell can't do that part), then come back here and run the cell below.

# %%
import os

from dotenv import load_dotenv
from IPython.display import Markdown, display

from research_crew.crew import ResearchCrew

load_dotenv()
os.makedirs("output", exist_ok=True)

# Same topic as steps 1-2. Keep it the same across all 5 steps.
TOPIC = "Explain the EU AI Act in simple terms for a 10-year-old in a short paragraph."

result = ResearchCrew().crew().kickoff(inputs={"topic": TOPIC})
display(Markdown(result.raw))

# %% [markdown]
# ## After running
#
# - Read the verbose log above the final output — this is the first time you see the agent's internal reasoning, not just the final answer.
# - Compare the output to step 2's. Does the agent break the task into sub-steps? Does it feel different?
# - Fill in the **Step 3** section of `EVALUATION.md`.
#
# Full instructions, background, and the stretch goal: [03-single-agent.md](03-single-agent.md).
