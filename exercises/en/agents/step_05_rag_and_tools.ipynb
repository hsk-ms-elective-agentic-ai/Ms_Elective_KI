# %% [markdown]
# # Step 5 — RAG + Tools (Runner)
#
# 🇬🇧 **English** (this notebook)
#
# This notebook just **runs and displays** your crew — for the full background, citations, and editing instructions, see [05-rag-and-tools.md](05-rag-and-tools.md). Add your knowledge document, wire up `SerperDevTool()` and `knowledge_sources` in `crew.py` first (a notebook cell can't do that part), then come back here and run the cell below.

# %%
import os

from dotenv import load_dotenv
from IPython.display import Markdown, display

from research_crew.crew import ResearchCrew

load_dotenv()
os.makedirs("output", exist_ok=True)

# Same topic as steps 1-2. Keep it the same across all 5 steps.
TOPIC = "Explain the EU AI Act in simple terms for a 10-year-old in a short paragraph."

result = ResearchCrew().crew().kickoff(inputs={"topic": TOPIC})
display(Markdown(result.raw))

# %% [markdown]
# ## After running
#
# - Check the verbose log: can you see when the agent calls the search tool, and what query it used?
# - Now comment out `knowledge_sources` in `crew.py` and run this cell again — does the agent still answer your document-specific question correctly, or does it admit it doesn't know? That comparison is the point of RAG.
# - Fill in the **Step 5** section of `EVALUATION.md` and your final recommendation.
#
# Full instructions, background, and the stretch goal (PDF knowledge sources): [05-rag-and-tools.md](05-rag-and-tools.md).
