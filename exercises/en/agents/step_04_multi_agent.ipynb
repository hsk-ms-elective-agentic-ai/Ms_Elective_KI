# %% [markdown]
# # Step 4 — Multi-Agent (Runner)
#
# 🇬🇧 **English** (this notebook)
#
# This notebook just **runs and displays** your crew — for the full background, citations, and editing instructions, see [04-multi-agent.md](04-multi-agent.md). Edit `agents.yaml`, `tasks.yaml`, and `crew.py` as real files first (a notebook cell can't do that part), then come back here and run the cell below.

# %%
import os

from dotenv import load_dotenv
from IPython.display import Markdown, display

from research_crew.crew import ResearchCrew

load_dotenv()
os.makedirs("output", exist_ok=True)

# Same topic as steps 1-2. Keep it the same across all 5 steps.
TOPIC = "Explain the EU AI Act in simple terms for a 10-year-old in a short paragraph."

result = ResearchCrew().crew().kickoff(inputs={"topic": TOPIC})
display(Markdown(result.raw))

# %% [markdown]
# ## After running
#
# - Read both agents' verbose output. Does the second agent build on or push back against the first, or mostly repackage the same content?
# - Does the final output feel qualitatively different from step 3?
# - **Experiment**: remove the `context:` line from the second task in `tasks.yaml` and run this cell again. What happens when the second agent can no longer see the first agent's work?
# - Fill in the **Step 4** section of `EVALUATION.md`.
#
# Full instructions, background, and the stretch goal: [04-multi-agent.md](04-multi-agent.md).
